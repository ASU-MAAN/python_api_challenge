# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 588

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url="http://api.openweathermap.org/data/2.5/weather?"
units="imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

City_name_list=[]
Lat_list=[]
Lng_list=[]
Max_Temp_list=[]
Humidity_list=[]
Cloud_list=[]
Wind_Speed_list=[]
Country_list=[]
Date_list=[]
cntr=0
ex_cntr=0
print('Beginning Data Retrieval')
for city in cities :
    response=requests.get(query_url + city).json()
    #city_name=
    try:
        City_name_list.append(response['name'])
        Lat_list.append(response['coord']['lat'])
        Lng_list.append(response['coord']['lon'])
        Max_Temp_list.append(response['main']['temp_max'])
        Humidity_list.append(response['main']['humidity'])
        Cloud_list.append(response['clouds']['all'])
        Wind_Speed_list.append(response['wind']['speed'])
        Country_list.append(response['sys']['country'])
        Date_list.append(response['dt'])
        cntr=cntr+1
        print(f'Processing Record {cntr} | {city}')
    except:
        print("That record does not exist, searching for next record...")
        ex_cntr=ex_cntr+1
print(f'Number of records processed:{cntr}')
print(f'Number of records that does not exist:{ex_cntr}')
# Out:
# Beginning Data Retrieval
# Processing Record 1 | nanakuli
# Processing Record 2 | talnakh
# Processing Record 3 | tiksi
# That record does not exist, searching for next record...
# Processing Record 4 | nouadhibou
# Processing Record 5 | erdenet
# Processing Record 6 | lebu
# Processing Record 7 | golpazari
# Processing Record 8 | ilulissat
# Processing Record 9 | hawaiian paradise park
# Processing Record 10 | albany
# Processing Record 11 | whitehorse
# Processing Record 12 | port-aux-francais
# Processing Record 13 | college
# Processing Record 14 | tafuna
# Processing Record 15 | puerto natales
# Processing Record 16 | adamstown
# Processing Record 17 | grytviken
# Processing Record 18 | west island
# Processing Record 19 | ta'izz
# Processing Record 20 | kodiak
# Processing Record 21 | blackmans bay
# Processing Record 22 | longyearbyen
# Processing Record 23 | olonkinbyen
# Processing Record 24 | constantia
# Processing Record 25 | sos'va
# That record does not exist, searching for next record...
# Processing Record 26 | iqaluit
# Processing Record 27 | rebrikha
# Processing Record 28 | thompson
# Processing Record 29 | namibe
# Processing Record 30 | asbury
# Processing Record 31 | revda
# Processing Record 32 | nuku'alofa
# Processing Record 33 | badger
# Processing Record 34 | edinburgh of the seven seas
# Processing Record 35 | qaqortoq
# Processing Record 36 | haiku-pauwela
# Processing Record 37 | concordia
# Processing Record 38 | kholmsk
# Processing Record 39 | bethel
# Processing Record 40 | fale old settlement
# Processing Record 41 | port macquarie
# Processing Record 42 | waitangi
# Processing Record 43 | bikenibeu village
# Processing Record 44 | carnarvon
# Processing Record 45 | tanguieta
# Processing Record 46 | mossel bay
# Processing Record 47 | port mathurin
# Processing Record 48 | atafu village
# Processing Record 49 | veraval
# Processing Record 50 | afaahiti
# Processing Record 51 | isafjordur
# That record does not exist, searching for next record...
# Processing Record 52 | xapuri
# That record does not exist, searching for next record...
# Processing Record 53 | nema
# Processing Record 54 | laguna
# Processing Record 55 | la passe
# Processing Record 56 | labytnangi
# Processing Record 57 | tazovsky
# Processing Record 58 | ta`u
# Processing Record 59 | midvagur
# Processing Record 60 | fort bragg
# Processing Record 61 | kristiansund
# Processing Record 62 | inarajan village
# Processing Record 63 | margaret river
# Processing Record 64 | lihue
# Processing Record 65 | quatre cocos
# Processing Record 66 | hermanus
# Processing Record 67 | invercargill
# Processing Record 68 | georgetown
# Processing Record 69 | alsunga
# Processing Record 70 | belgrade
# That record does not exist, searching for next record...
# Processing Record 71 | papatowai
# Processing Record 72 | ushuaia
# Processing Record 73 | ust'-kulom
# Processing Record 74 | saynshand
# Processing Record 75 | nyurba
# Processing Record 76 | avarua
# Processing Record 77 | jelgava
# Processing Record 78 | yellowknife
# Processing Record 79 | piti village
# Processing Record 80 | al mishkhab
# Processing Record 81 | benghazi
# That record does not exist, searching for next record...
# Processing Record 82 | borazjan
# Processing Record 83 | howrah
# Processing Record 84 | puerto ayora
# Processing Record 85 | isla vista
# Processing Record 86 | codrington
# Processing Record 87 | howard springs
# Processing Record 88 | utrik
# Processing Record 89 | fort st. john
# Processing Record 90 | enewetak
# Processing Record 91 | ancud
# Processing Record 92 | pontianak
# Processing Record 93 | jamestown
# Processing Record 94 | vila franca do campo
# Processing Record 95 | leava
# Processing Record 96 | luderitz
# Processing Record 97 | sinazongwe
# Processing Record 98 | newman
# Processing Record 99 | uturoa
# Processing Record 100 | kerikeri
# Processing Record 101 | wailua homesteads
# Processing Record 102 | iskateley
# Processing Record 103 | labuan
# Processing Record 104 | darwin
# Processing Record 105 | broome
# Processing Record 106 | cabo san lucas
# Processing Record 107 | queenstown
# Processing Record 108 | acarau
# Processing Record 109 | ribeira grande
# Processing Record 110 | visakhapatnam
# Processing Record 111 | akureyri
# Processing Record 112 | itoman
# Processing Record 113 | general pico
# Processing Record 114 | lucerne valley
# That record does not exist, searching for next record...
# Processing Record 115 | qalat
# Processing Record 116 | sabang
# Processing Record 117 | al fulah
# Processing Record 118 | san patricio
# Processing Record 119 | touros
# Processing Record 120 | konstantinovka
# Processing Record 121 | aykhal
# Processing Record 122 | chernyshevskiy
# Processing Record 123 | juterbog
# Processing Record 124 | chibougamau
# Processing Record 125 | dadukou
# Processing Record 126 | hamilton
# Processing Record 127 | rongelap
# Processing Record 128 | new norfolk
# Processing Record 129 | louisville
# Processing Record 130 | mount isa
# Processing Record 131 | ndende
# Processing Record 132 | aasiaat
# Processing Record 133 | mermoz boabab
# Processing Record 134 | bandarbeyla
# Processing Record 135 | conde
# Processing Record 136 | port elizabeth
# Processing Record 137 | bamboo flat
# Processing Record 138 | auki
# Processing Record 139 | gadzhiyevo
# Processing Record 140 | keflavik
# Processing Record 141 | bredasdorp
# That record does not exist, searching for next record...
# Processing Record 142 | pathein
# Processing Record 143 | east london
# Processing Record 144 | forster
# That record does not exist, searching for next record...
# That record does not exist, searching for next record...
# Processing Record 145 | saint-francois
# That record does not exist, searching for next record...
# Processing Record 146 | udachny
# Processing Record 147 | porto novo
# Processing Record 148 | igarka
# Processing Record 149 | aripuana
# Processing Record 150 | arraial do cabo
# Processing Record 151 | santiago
# Processing Record 152 | bilibino
# Processing Record 153 | hengyang
# That record does not exist, searching for next record...
# Processing Record 154 | san antonio de pale
# Processing Record 155 | saipan
# Processing Record 156 | nar'yan-mar
# Processing Record 157 | itarsi
# Processing Record 158 | nantucket
# Processing Record 159 | bereket
# Processing Record 160 | punta arenas
# Processing Record 161 | ust-nera
# Processing Record 162 | ibate
# Processing Record 163 | mahina
# Processing Record 164 | kathu
# Processing Record 165 | usinsk
# Processing Record 166 | portland
# Processing Record 167 | taltal
# Processing Record 168 | siwa oasis
# Processing Record 169 | lander
# Processing Record 170 | hithadhoo
# Processing Record 171 | nuuk
# Processing Record 172 | sobral
# Processing Record 173 | scone
# Processing Record 174 | novodvinsk
# Processing Record 175 | aras-asan
# Processing Record 176 | chake chake
# Processing Record 177 | bunia
# That record does not exist, searching for next record...
# Processing Record 178 | sao jose da coroa grande
# Processing Record 179 | tianshui
# Processing Record 180 | barra de santo antonio
# Processing Record 181 | znamenskoye
# Processing Record 182 | port alfred
# Processing Record 183 | san juan de miraflores
# Processing Record 184 | trondheim
# Processing Record 185 | kapa'a
# Processing Record 186 | weno
# Processing Record 187 | ebon
# Processing Record 188 | okhotsk
# Processing Record 189 | douentza
# Processing Record 190 | agustin codazzi
# Processing Record 191 | guerrero negro
# Processing Record 192 | general conesa
# Processing Record 193 | pisco
# Processing Record 194 | ad dilam
# Processing Record 195 | baiyin
# Processing Record 196 | bukoba
# Processing Record 197 | tura
# Processing Record 198 | sake
# Processing Record 199 | lorengau
# Processing Record 200 | fisterra
# That record does not exist, searching for next record...
# Processing Record 201 | nishinoomote
# Processing Record 202 | island harbour
# Processing Record 203 | kuchera
# Processing Record 204 | praia da vitoria
# Processing Record 205 | la ronge
# Processing Record 206 | minas de marcona
# Processing Record 207 | oranjemund
# Processing Record 208 | dunhua
# Processing Record 209 | stanley
# Processing Record 210 | pemangkat
# Processing Record 211 | jinghong
# Processing Record 212 | uruacu
# Processing Record 213 | gao
# Processing Record 214 | haines city
# Processing Record 215 | kingston
# Processing Record 216 | bonthe
# Processing Record 217 | ataq
# Processing Record 218 | anadyr
# Processing Record 219 | aioun
# Processing Record 220 | savanna-la-mar
# Processing Record 221 | selma
# Processing Record 222 | bafoulabe
# Processing Record 223 | shitanjing
# Processing Record 224 | barcelos
# Processing Record 225 | san julian
# Processing Record 226 | nagqu
# Processing Record 227 | tual
# Processing Record 228 | shendi
# Processing Record 229 | isiro
# Processing Record 230 | ust'-kalmanka
# Processing Record 231 | burang
# Processing Record 232 | thunder bay
# Processing Record 233 | bergneustadt
# Processing Record 234 | vanimo
# Processing Record 235 | aqsay
# Processing Record 236 | dudinka
# Processing Record 237 | knyaze-volkonskoye
# That record does not exist, searching for next record...
# Processing Record 238 | bongaree
# Processing Record 239 | mar del plata
# Processing Record 240 | alice springs
# Processing Record 241 | abilene
# Processing Record 242 | todos santos
# Processing Record 243 | rolla
# Processing Record 244 | dubbo
# Processing Record 245 | nabire
# Processing Record 246 | quellon
# Processing Record 247 | artist village
# Processing Record 248 | la sarre
# Processing Record 249 | yuzhno-kurilsk
# Processing Record 250 | zyryanskoye
# Processing Record 251 | matozinhos
# Processing Record 252 | peace river
# Processing Record 253 | kitimat
# Processing Record 254 | jaguey grande
# Processing Record 255 | ystalyfera
# Processing Record 256 | tumaco
# Processing Record 257 | harper
# Processing Record 258 | kruisfontein
# Processing Record 259 | mulanje
# Processing Record 260 | nizhnesortymskiy
# Processing Record 261 | port hueneme
# Processing Record 262 | belyy yar
# Processing Record 263 | sitka
# Processing Record 264 | amursk
# Processing Record 265 | santa ana
# Processing Record 266 | al hudaydah
# Processing Record 267 | vorgashor
# Processing Record 268 | tralee
# Processing Record 269 | tazacorte
# Processing Record 270 | puerto baquerizo moreno
# Processing Record 271 | woodward
# Processing Record 272 | spezzano albanese
# Processing Record 273 | pitimbu
# Processing Record 274 | vilyuchinsk
# Processing Record 275 | chavusy
# Processing Record 276 | maraba
# Processing Record 277 | shingu
# Processing Record 278 | sao vicente
# Processing Record 279 | sinjai
# Processing Record 280 | ceelbuur
# Processing Record 281 | bhainsdehi
# Processing Record 282 | verkhnevilyuysk
# Processing Record 283 | arkhangel'sk
# Processing Record 284 | zaozersk
# Processing Record 285 | amet
# Processing Record 286 | teknaf
# Processing Record 287 | macapa
# Processing Record 288 | dazhou
# Processing Record 289 | kingscliff
# Processing Record 290 | puerto leguizamo
# Processing Record 291 | klyuchi
# Processing Record 292 | coquimbo
# Processing Record 293 | san luis de la loma
# Processing Record 294 | cole harbour
# Processing Record 295 | axim
# Processing Record 296 | morant bay
# Processing Record 297 | kinkala
# Processing Record 298 | selfoss
# That record does not exist, searching for next record...
# Processing Record 299 | alpine
# Processing Record 300 | gebeit
# Processing Record 301 | yanliang
# Processing Record 302 | porto santo stefano
# Processing Record 303 | ozersk
# Processing Record 304 | muleba
# Processing Record 305 | solnechnyy
# Processing Record 306 | skuodas
# Processing Record 307 | papao
# Processing Record 308 | canutama
# Processing Record 309 | rikaze
# Processing Record 310 | vadso
# Processing Record 311 | takoradi
# Processing Record 312 | kyshtovka
# Processing Record 313 | saint-joseph
# That record does not exist, searching for next record...
# Processing Record 314 | kavieng
# Processing Record 315 | noumea
# Processing Record 316 | port lincoln
# Processing Record 317 | santa cruz
# Processing Record 318 | northam
# Processing Record 319 | gamay
# That record does not exist, searching for next record...
# Processing Record 320 | xinyuan
# Processing Record 321 | kent
# Processing Record 322 | sisimiut
# Processing Record 323 | smithers
# Processing Record 324 | bria
# Processing Record 325 | mirny
# Processing Record 326 | owando
# Processing Record 327 | bowen
# Processing Record 328 | yangambi
# Processing Record 329 | donnacona
# Processing Record 330 | hasaki
# Processing Record 331 | nadi
# That record does not exist, searching for next record...
# Processing Record 332 | ciudad lazaro cardenas
# Processing Record 333 | egilsstadir
# Processing Record 334 | valparaiso
# Processing Record 335 | kavaratti
# Processing Record 336 | sinabang
# Processing Record 337 | sibay
# Processing Record 338 | kribi
# Processing Record 339 | mityana
# Processing Record 340 | susuman
# Processing Record 341 | campamento
# Processing Record 342 | brak
# Processing Record 343 | magdagachi
# Processing Record 344 | taroa
# Processing Record 345 | dunkirk
# Processing Record 346 | lerwick
# Processing Record 347 | keokuk
# Processing Record 348 | acajutla
# Processing Record 349 | lesnoy
# Processing Record 350 | lucapa
# Processing Record 351 | bembereke
# Processing Record 352 | shahpura
# Processing Record 353 | nova sintra
# Processing Record 354 | vilyuysk
# Processing Record 355 | bacalar
# Processing Record 356 | salalah
# That record does not exist, searching for next record...
# Processing Record 357 | bay roberts
# Processing Record 358 | sambava
# Processing Record 359 | guarapari
# Processing Record 360 | dolores
# Processing Record 361 | mount gambier
# Processing Record 362 | korhogo
# Processing Record 363 | palikir - national government center
# Processing Record 364 | zoucheng
# Processing Record 365 | anchorage
# Processing Record 366 | de aar
# Processing Record 367 | machico
# Processing Record 368 | cidreira
# Processing Record 369 | buka
# Processing Record 370 | gering
# Processing Record 371 | fatsa
# Processing Record 372 | port augusta
# Processing Record 373 | khouribga
# Processing Record 374 | hermiston
# Processing Record 375 | katabu
# Processing Record 376 | zeya
# Processing Record 377 | puerto aysen
# Processing Record 378 | petropavlovsk-kamchatsky
# Processing Record 379 | fort mcmurray
# Processing Record 380 | yemva
# Processing Record 381 | dakoro
# Processing Record 382 | ostersund
# Processing Record 383 | achit
# Processing Record 384 | hastings
# Processing Record 385 | key largo
# Processing Record 386 | san carlos de bariloche
# Processing Record 387 | lugazi
# Processing Record 388 | nguigmi
# Processing Record 389 | nosy varika
# Processing Record 390 | albertina
# Processing Record 391 | rio grande
# Processing Record 392 | sedrata
# Processing Record 393 | pangody
# Processing Record 394 | pontian kechil
# Processing Record 395 | lagunas
# Processing Record 396 | tolanaro
# Processing Record 397 | olyokminsk
# Processing Record 398 | mejit
# Processing Record 399 | banda aceh
# Processing Record 400 | vila velha
# Processing Record 401 | buala
# Processing Record 402 | tabou
# Processing Record 403 | port saint john's
# Processing Record 404 | argo
# Processing Record 405 | colonia
# Processing Record 406 | luganville
# Processing Record 407 | kourou
# Processing Record 408 | uvalde
# Processing Record 409 | north battleford
# Processing Record 410 | qamdo
# Processing Record 411 | kone
# Processing Record 412 | kayangel
# Processing Record 413 | margate
# Processing Record 414 | dalai
# Processing Record 415 | palmas
# Processing Record 416 | garachico
# Processing Record 417 | ulsteinvik
# Processing Record 418 | remire-montjoly
# Processing Record 419 | okha
# Processing Record 420 | jayapura
# Processing Record 421 | rauco
# Processing Record 422 | ponta delgada
# Processing Record 423 | wahpeton
# Processing Record 424 | aitape
# Processing Record 425 | novoishimskiy
# Processing Record 426 | wotho
# Processing Record 427 | kununurra
# Processing Record 428 | korla
# Processing Record 429 | choyr
# Processing Record 430 | swan hill
# Processing Record 431 | pacific grove
# Processing Record 432 | umm kaddadah
# Processing Record 433 | soio
# Processing Record 434 | gaoual
# Processing Record 435 | bayonne
# Processing Record 436 | quesnel
# Processing Record 437 | le port
# Processing Record 438 | fortuna
# Processing Record 439 | rey bouba
# Processing Record 440 | luena
# Processing Record 441 | al kharj
# Processing Record 442 | laascaanood
# Processing Record 443 | box elder
# Processing Record 444 | sosnogorsk
# Processing Record 445 | parun
# Processing Record 446 | lompoc
# Processing Record 447 | birao
# Processing Record 448 | mumford
# Processing Record 449 | mount pearl
# Processing Record 450 | sona
# Processing Record 451 | punto fijo
# Processing Record 452 | waingapu
# Processing Record 453 | kijang
# Processing Record 454 | leh
# Processing Record 455 | jagatsinghapur
# Processing Record 456 | yoko
# Processing Record 457 | progreso
# Processing Record 458 | saint-philippe
# Processing Record 459 | al khawr
# Processing Record 460 | jamjamal
# Processing Record 461 | qazax
# Processing Record 462 | paso de los libres
# Processing Record 463 | awjilah
# Processing Record 464 | essaouira
# Processing Record 465 | alamos
# Processing Record 466 | kilindoni
# Processing Record 467 | am timan
# Processing Record 468 | shimoda
# Processing Record 469 | callao
# Processing Record 470 | bechar
# Processing Record 471 | moyo
# Processing Record 472 | ventnor
# Processing Record 473 | dongola
# Processing Record 474 | djibo
# Processing Record 475 | pimentel
# Processing Record 476 | bridgewater
# That record does not exist, searching for next record...
# Processing Record 477 | pionerskiy
# Processing Record 478 | lindisfarne
# Processing Record 479 | isola delle femmine
# Processing Record 480 | mili
# Processing Record 481 | palmer
# Processing Record 482 | cromwell
# Processing Record 483 | lepsy
# Processing Record 484 | ash shihaniyah
# Processing Record 485 | greenville
# Processing Record 486 | naze
# Processing Record 487 | sumberpucung
# Processing Record 488 | semenov
# Processing Record 489 | copiapo
# Processing Record 490 | twon-brass
# Processing Record 491 | st. john's
# Processing Record 492 | kamina
# That record does not exist, searching for next record...
# Processing Record 493 | castillos
# Processing Record 494 | geraldton
# Processing Record 495 | muroto-misakicho
# Processing Record 496 | sao gabriel da cachoeira
# Processing Record 497 | ushibukamachi
# Processing Record 498 | ko pha ngan
# Processing Record 499 | dera ghazi khan
# Processing Record 500 | springbok
# Processing Record 501 | juan griego
# Processing Record 502 | sorong
# Processing Record 503 | ouadda
# Processing Record 504 | iquique
# Processing Record 505 | arno
# Processing Record 506 | puerto armuelles
# Processing Record 507 | amos
# Processing Record 508 | ballina
# Processing Record 509 | san javier
# Processing Record 510 | teluk nibung
# Processing Record 511 | greymouth
# Processing Record 512 | dalbandin
# Processing Record 513 | coronado
# Processing Record 514 | kaka
# Processing Record 515 | yamba
# Processing Record 516 | zarand
# That record does not exist, searching for next record...
# Processing Record 517 | perm
# Processing Record 518 | timimoun
# Processing Record 519 | mongo
# Processing Record 520 | mega
# Processing Record 521 | kongsvinger
# Processing Record 522 | alva
# Processing Record 523 | chyhyryn
# Processing Record 524 | tsiombe
# Processing Record 525 | vakhsh
# Processing Record 526 | mirnyy
# Processing Record 527 | sinop
# Processing Record 528 | kandyagash
# Processing Record 529 | glace bay
# Processing Record 530 | chengde
# Processing Record 531 | pervomayskoye
# That record does not exist, searching for next record...
# Processing Record 532 | boende
# Processing Record 533 | tongliao
# Processing Record 534 | pauini
# Processing Record 535 | trail
# That record does not exist, searching for next record...
# Processing Record 536 | weleri
# Processing Record 537 | mboursou lere
# Processing Record 538 | ananindeua
# Processing Record 539 | bandar lampung
# Processing Record 540 | yicheng
# Processing Record 541 | berezovyy
# Processing Record 542 | bonab
# Processing Record 543 | alesund
# That record does not exist, searching for next record...
# Processing Record 544 | adrar
# That record does not exist, searching for next record...
# Processing Record 545 | nabari
# Processing Record 546 | prince rupert
# Processing Record 547 | aracruz
# Processing Record 548 | eureka
# Processing Record 549 | armyansk
# Processing Record 550 | makurdi
# Processing Record 551 | robore
# Processing Record 552 | puerto lleras
# Processing Record 553 | whitefish
# Processing Record 554 | mpika
# Processing Record 555 | manokwari
# Processing Record 556 | trn
# Processing Record 557 | mata-utu
# Processing Record 558 | beckley
# Processing Record 559 | marsh harbour
# Processing Record 560 | tlaltenango de sanchez roman
# Processing Record 561 | bengkulu
# Number of records processed:561
# Number of records that does not exist:27

# %%
# Convert the cities weather data into a Pandas DataFrame

# Count data
weather_dict = pd.DataFrame({ 
                "City" : City_name_list,
                "Cloudiness" : Cloud_list,
                "Country" : Country_list,
                "Date" : Date_list,
                "Humidity" : Humidity_list,
                "Lat" : Lat_list,
                "Lng" : Lng_list,
                "Max Temp" : Max_Temp_list,
                "Wind Speed" : Wind_Speed_list
})
weather_dict.count()
# Out:
# City          561
# Cloudiness    561
# Country       561
# Date          561
# Humidity      561
# Lat           561
# Lng           561
# Max Temp      561
# Wind Speed    561
# dtype: int64

# %%
# Display sample data
weather_dict
# Out:
#                              City  Cloudiness Country        Date  Humidity  \
# 0                        Nānākuli         100      US  1692240975        52
# 1                         Talnakh           0      RU  1692240975        55
# 2                           Tiksi         100      RU  1692240975        95
# 3                      Nouadhibou          20      MR  1692240976        78
# 4                         Erdenet          30      MN  1692240976        66
# ..                            ...         ...     ...         ...       ...
# 556                      Mata-Utu           2      WF  1692241129        74
# 557                       Beckley          20      US  1692241008        94
# 558                 Marsh Harbour         100      BS  1692241129        78
# 559  Tlaltenango de Sánchez Román          94      MX  1692241129        41
# 560                      Bengkulu          15      ID  1692241130        70
#
#          Lat       Lng  Max Temp  Wind Speed
# 0    21.3906 -158.1547     87.75       11.50
# 1    69.4865   88.3972     55.38        0.65
# 2    71.6872  128.8694     38.46        9.28
# 3    20.9310  -17.0347     78.78        6.91
# 4    49.0333  104.0833     57.65        4.05
# ..       ...       ...       ...         ...
# 556 -13.2816 -176.1745     82.17       13.98
# 557  37.7782  -81.1882     63.01        0.00
# 558  26.5412  -77.0636     84.40       14.63
# 559  21.7833 -103.3167     73.29        8.70
# 560  -3.8004  102.2655     83.03        8.03
#
# [561 rows x 9 columns]

# %%
#Export DataFrame to CSV File
weather_dict.to_csv("output_data/cities.csv", index = False)

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("City Latitude vs Max Temperature.png")

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("City Latitude vs Humidity.png")

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("City Latitude vs Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph) (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
northern_df = weather_dict.loc[pd.to_numeric(weather_dict["Lat"]).astype(float) > 0, :]
southern_df = weather_dict.loc[pd.to_numeric(weather_dict["Lat"]).astype(float) < 0, :]

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
plt.savefig(" northren hemisphere temp vs lat.png")
# Out:
# Regression line equation is: y = -0.37x + 85.99
# The r-squared is: -0.5956276333279337
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %%
# Linear regression on Southern Hemisphere
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
plt.savefig("southern hemisphere lat vs max temp.png")
# Out:
# Regression line equation is: y = 0.74x + 82.6
# The r-squared is: 0.7911028270024576
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()

# Save the figure
plt.savefig("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# Regression line equation is: y = -0.06x + 74.49
# The r-squared is: -0.05397423129544836
# The regression does not display much of a correlation between the data sets.

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
plt.savefig("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# Regression line equation is: y = -0.02x + 71.56
# The r-squared is: -0.020485742177121857
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
plt.savefig("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression.png")
# Out:
# Regression line equation is: y = -0.31x + 67.03
# The r-squared is: -0.1512321147065109
# The regression does not display much of a correlation between the data sets.

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
plt.savefig("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression.png")
# Out:
# Regression line equation is: y = -0.43x + 45.15
# The r-squared is: -0.15958860218095858
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
plt.savefig("Northern Hemisphere - Wind speed vs. Latitude Linear Regression.png")
# Out:
# Regression line equation is: y = -0.0x + 7.15
# The r-squared is: -0.019665267098204472
# The regression does not display much of a correlation between the data sets.

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
plt.savefig("Southern Hemisphere - wind speed vs. Latitude Linear Regression.png")
# Out:
# Regression line equation is: y = -0.05x + 7.21
# The r-squared is: -0.12249229480332166
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
